# %%
#
# Pythonおみくじ
#
import random

omikuji = random.choice(["大吉","中吉","小吉","吉","凶"])
print(omikuji)

# %%
#
# Pythonおみくじ
#
import random

data = ["大吉","中吉","小吉","吉","凶"]

omikuji = random.choice(data)
print(omikuji)

# %%
#
# Pythonおみくじ
#
import random

data = ["大吉","中吉","小吉","吉","凶"]

number = random.randrange(0,5)
print(data[number], number)

# %%
#
# Pythonおみくじ
#
import random

data = ["大吉","中吉","小吉","吉","凶"]

i = 0
print(data[i],i)
i = i + 1
print(data[i],i)
i = i + 1
print(data[i],i)
i = i + 1
print(data[i],i)
i = i + 1
print(data[i],i)
