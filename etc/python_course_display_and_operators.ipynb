# %% [markdown]
# # Pythonコース（文字と数字の表示と計算記号）

# %%
print("Hello, world")

# %%
print('Hello, world')

# %%
print(5 + 10)

# %%
print(10 - 5)

# %%
print(5 * 10)

# %%
print(5 / 10)

# %%
print(29 % 3)

# %%
print('5 * 10 =', 5 * 10)

# %% [markdown]
# # 試してみよう
# 上に書いた計算以外の計算を下の欄を使って色々試してみよう。
