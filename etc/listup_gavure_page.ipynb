# %% [markdown]
# <a href="https://colab.research.google.com/github/kwaka1208/colab/blob/main/gather_linked_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import urllib.error, urllib.parse
from urllib.parse import urljoin
from bs4 import BeautifulSoup
import re
import os

targets = [
  'https://gravurezasshi9.doorblog.jp/',
  'http://gravurezasshi7.livedoor.blog/',
  'https://magazinejapanese6.blog.jp/',
  'https://magazinejapanese5.blog.jp/',
  'https://magazinejapanese4.doorblog.jp/',
  'https://magazinejapanese3.blog.jp/',
  'https://magazinejapanese.blog.jp/',
  'https://magazinejapanese.blog.jp/',
]

for url in targets:
    html = urllib.request.urlopen(url)
    soup = BeautifulSoup(html, "html.parser")
    title = soup.find('title').getText()
    try：
      last = soup.find('li', class_='paging-last')
      last = last.find('a').get('href')
    except Exception as e:
      print(e)
      pass
    print(last)
    last_page = int(last.split('?p=')[1])
    baseurl = last.split('?p=')[0]
    print('==================')
    print(title)
    for i in range(1, last_page+1):
        page_url = urljoin(baseurl, '?p=' + str(i))
        html = urllib.request.urlopen(url)
        soup = BeautifulSoup(html, "html.parser")
        data = soup.find_all('dt')
        print('------------------')
        print('page: ',str(i))
        for element in data:
            print(element.find('a').getText())
            print(element.find('a').get('href'))
            # print(element.find('img').get('src'))
            # print(element.find('img').get('alt'))
            print('------------------')
        print('==================')
