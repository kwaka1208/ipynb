# %% [markdown]
# <a href="https://colab.research.google.com/github/kwaka1208/colab/blob/main/%E5%A4%89%E6%95%B0%E3%83%BB%E5%AE%9A%E6%95%B0%E3%83%BB%E9%96%A2%E6%95%B0%E3%81%A8%E3%83%A2%E3%82%B8%E3%83%A5%E3%83%BC%E3%83%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pythonの例（戻り値のない関数）

def circle(hankei):
    print("半径", hankei, "cmの時")
    print("面積は", hankei * hankei * 3.14, "cm2")
    print("\n")

circle(5)


# Pythonの例（戻り値のある関数）

def double(number):
    return number * 2

print(double(5))

# %%
# カレンダーを出力するモジュール

import calendar

print(calendar.month(2022, 12))
