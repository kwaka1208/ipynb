# %% [markdown]
# # 図形を描こう
# ## STEP1
# 以下のプログラムを入力して、動かしてみよう。
# 描けた図形の名前をチャットに投稿してください。
#
# プログラムをコピーしてもいいけど、できるだけ自分で入力してみよう。
#
# ```
# !pip3 install ColabTurtle
# from ColabTurtle.Turtle import *
# initializeTurtle(initial_speed=5)
# color('red')
# bgcolor('white')
#
# forward(100)
# left(90)
# forward(100)
# left(90)
# forward(100)
# left(90)
# forward(100)
# left(90)
# ```

# %% [markdown]
# ## STEP2
# 上の図形が描けたら、このプログラムを変えて正三角形を描いてみてください。
# 以下の部分だけをしたのコードエリアにコピーして、正三角形のプログラムに改変してください。
# ```
# forward(100)
# left(90)
# forward(100)
# left(90)
# forward(100)
# left(90)
# forward(100)
# left(90)
# ```

# %% [markdown]
# ## STEP3
# 次は、正五角形を描いてみてください。

# %% [markdown]
# ## STEP4
# 最後は、正七角形を描いてみてください。

# %% [markdown]
# ## STEP5
# さぁ、ここまでである法則に気づきませんでしたか？
# 色んな正多角形を描くプログラムを作ってみましょう。

# %% [markdown]
# ## フリータイム
# ここまで終わったら、後は自由にプログラミングしてもらってOKです。
