# %% [markdown]
# # 変数と繰り返しで図形を描く

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *
initializeTurtle(initial_speed=5)
color('red')
bgcolor('white')

kaku = 30
for i in range(kaku):
  forward(50)
  left(360 / kaku)
print('正',kaku,'角形です')
